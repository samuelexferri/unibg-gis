# %%
import xarray as xr
ds = xr.open_dataset('datasets/S5P_OFFL_L3__NO2____20200310T111355_20200310T125526_12472_01_010302_20200313T160857.nc')
df = ds.to_dataframe()

ds
# Out:
# <xarray.Dataset>
# Dimensions:                                      (independent_2: 2, latitude: 499, longitude: 999, time: 1, vertical: 34)
# Coordinates:
#   * latitude                                     (latitude) float64 42.0 ... ...
#   * longitude                                    (longitude) float64 5.005 .....
# Dimensions without coordinates: independent_2, time, vertical
# Data variables:
#     datetime_start                               (time) datetime64[ns] 2020-0...
#     datetime_length                              float32 0.84
#     orbit_index                                  int32 12472
#     sensor_altitude                              (time, latitude, longitude) float64 ...
#     solar_zenith_angle                           (time, latitude, longitude) float64 ...
#     solar_azimuth_angle                          (time, latitude, longitude) float64 ...
#     sensor_zenith_angle                          (time, latitude, longitude) float64 ...
# ...

# %%
df
# Out:
#                                                         datetime_start  \
# independent_2 latitude longitude time vertical
# 0             42.005   5.005     0    0        2020-03-10 12:16:44.007
#                                       1        2020-03-10 12:16:44.007
#                                       2        2020-03-10 12:16:44.007
#                                       3        2020-03-10 12:16:44.007
#                                       4        2020-03-10 12:16:44.007
# ...                                                                ...
# 1             46.985   14.985    0    29       2020-03-10 12:16:44.007
#                                       30       2020-03-10 12:16:44.007
#                                       31       2020-03-10 12:16:44.007
#                                       32       2020-03-10 12:16:44.007
#                                       33       2020-03-10 12:16:44.007
#
# ...

# %%
import netCDF4
nc = netCDF4.Dataset('datasets/S5P_OFFL_L3__NO2____20200310T111355_20200310T125526_12472_01_010302_20200313T160857.nc')

nc
# Out:
# <class 'netCDF4._netCDF4.Dataset'>
# root group (NETCDF3_CLASSIC data model, file format NETCDF3):
#     Conventions: HARP-1.0
#     datetime_start: 7374.511620451389
#     datetime_stop: 7374.512689872686
#     source_product: S5P_OFFL_L2__NO2____20200310T111355_20200310T125526_12472_01_010302_20200313T160857.nc
# ...
