# %%
import datacube

dc = datacube.Datacube()

products_info = dc.list_products()

products_info
# Out:
#           name                            description   lon label format  \
# id
# 1   sentinel5p  Sentinel5P NetCDF with various layers  None  None   None
#
#    cloud_cover  time platform region_code creation_time instrument  \
# id
# 1         None  None     None        None          None       None
#
#    product_family dataset_maturity   lat  crs  resolution  tile_size  \
# id
# 1            None             None  None  NaN         NaN        NaN
#
#     spatial_dimensions
# id
# 1                  NaN

# %%
from shapely import speedups
speedups.disable()

# %%
product = 'sentinel5p'
sentinel5p_dataset = dc.load(product, output_crs="EPSG:4326", resolution=(-300, 300))

sentinel5p_dataset
# Out:
# c:\users\samuelexferri\env\lib\site-packages\datacube-0.0.0-py3.8.egg\datacube\storage\_rio.py:192: DeprecationWarning: Broken/missing geospatial data was found in file:
# "NetCDF:"C:\GitHub\unibg-gis\dataset.nc":cloud_pressure"
# Will use approximate metadata for backwards compatibility reasons (#673).
# This behaviour is deprecated. Future versions will raise an error.
#   warnings.warn(f"""Broken/missing geospatial data was found in file:
# <xarray.Dataset>
# Dimensions:         (latitude: 779, longitude: 772, time: 1)
# Coordinates:
#   * time            (time) datetime64[ns] 2020-01-01T07:02:54.188000
#   * latitude        (latitude) float64 -3.077e+06 -3.077e+06 ... -3.31e+06
#   * longitude       (longitude) float64 3.782e+05 3.784e+05 ... 6.094e+05
#     spatial_ref     int32 4326
# Data variables:
#     cloud_pressure  (time, latitude, longitude) float64 -1.0 -1.0 ... -1.0 -1.0
# Attributes:
#     crs:           EPSG:4326
#     grid_mapping:  spatial_ref

# %%
sentinel5p_dataset.cloud_pressure.dims
# Out:
# ('time', 'latitude', 'longitude')

# %%
sentinel5p_dataset.cloud_pressure.plot()
